# %%
import torch
from torch import nn,tensor,from_numpy,optim
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("diabetes_csv.csv")

# %%
df.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
df.describe()
# Out:
#              preg        plas        pres        skin        insu        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age
# count  768.000000  768.000000
# mean     0.471876   33.240885
# std      0.331329   11.760232
# min      0.078000   21.000000
# 25%      0.243750   24.000000
# 50%      0.372500   29.000000
# 75%      0.626250   41.000000
# ...

# %%
len(df.columns)
# Out:
# 9

# %%
for i in range (len(df)):
    if df.loc[i,"class"] == "tested_positive":
        df.loc[i,"class"] = 1
    if df.loc[i,"class"] == "tested_negative":
        df.loc[i,"class"] = 0

# %%
x_data = df[df.columns[0:8]].to_numpy()
x_data = x_data.astype(np.float32)
x_data = from_numpy(x_data)

# %%
y_data = df[["class"]].to_numpy()
y_data = y_data.astype(np.float32)
y_data = from_numpy(y_data)

# %%
print("Shape of X_data ", x_data.shape)
print("Shape of Y_data ", y_data.shape)
# Out:
# Shape of X_data  torch.Size([768, 8])
# Shape of Y_data  torch.Size([768, 1])

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model,self).__init__()
        
        self.l1 = nn.Linear(8, 6)
        self.l2 = nn.Linear(6, 4)
        self.l3 = nn.Linear(4, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        """
        In the forward function we accept a Variable of input data and we must return
        a Variable of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Variables.
        """
        out1 = self.sigmoid(self.l1(x))
        out2 = self.sigmoid(self.l2(out1))
        y_pred = self.sigmoid(self.l3(out2))
        return y_pred


# our model
model = Model()

# %%
criterion = nn.BCELoss(reduction='mean')
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(100):
    # Forward pass: Compute predicted y by passing x to the model
    y_pred = model(x_data)

    # Compute and print loss
    loss = criterion(y_pred, y_data)
    print(f'Epoch: {epoch + 1}/100 | Loss: {loss.item():.4f}')

    # Zero gradients, perform a backward pass, and update the weights.
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch: 1/100 | Loss: 0.6454
# Epoch: 2/100 | Loss: 0.6454
# Epoch: 3/100 | Loss: 0.6454
# Epoch: 4/100 | Loss: 0.6454
# Epoch: 5/100 | Loss: 0.6454
# Epoch: 6/100 | Loss: 0.6454
# Epoch: 7/100 | Loss: 0.6454
# Epoch: 8/100 | Loss: 0.6454
# Epoch: 9/100 | Loss: 0.6454
# Epoch: 10/100 | Loss: 0.6454
# Epoch: 11/100 | Loss: 0.6454
# Epoch: 12/100 | Loss: 0.6454
# Epoch: 13/100 | Loss: 0.6454
# Epoch: 14/100 | Loss: 0.6454
# Epoch: 15/100 | Loss: 0.6454
# Epoch: 16/100 | Loss: 0.6454
# Epoch: 17/100 | Loss: 0.6453
# Epoch: 18/100 | Loss: 0.6453
# Epoch: 19/100 | Loss: 0.6453
# Epoch: 20/100 | Loss: 0.6453
# Epoch: 21/100 | Loss: 0.6453
# Epoch: 22/100 | Loss: 0.6453
# Epoch: 23/100 | Loss: 0.6453
# Epoch: 24/100 | Loss: 0.6453
# Epoch: 25/100 | Loss: 0.6453
# Epoch: 26/100 | Loss: 0.6453
# Epoch: 27/100 | Loss: 0.6453
# Epoch: 28/100 | Loss: 0.6453
# Epoch: 29/100 | Loss: 0.6453
# Epoch: 30/100 | Loss: 0.6453
# Epoch: 31/100 | Loss: 0.6453
# Epoch: 32/100 | Loss: 0.6453
# ...
